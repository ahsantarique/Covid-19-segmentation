# %%
import pandas as pd

# %%
path = 'C:/Users/ah3wj/Desktop/epi-segmentation/'
df = pd.read_csv(path + 'covid-19-data/us-states.csv')

# %%
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
df_sorted = df.sort_values('state', ascending = True)

# %%
df_sorted
# Out:
#             date    state  fips  cases  deaths
# 1444  2020-03-29  Alabama     1    830       5
# 795   2020-03-17  Alabama     1     39       0
# 2049  2020-04-09  Alabama     1   2838      78
# 2777  2020-04-22  Alabama     1   5610     201
# 1281  2020-03-26  Alabama     1    538       3
# 2553  2020-04-18  Alabama     1   4723     147
# 1994  2020-04-08  Alabama     1   2499      67
# 903   2020-03-19  Alabama     1     78       0
# 2833  2020-04-23  Alabama     1   5832     197
# 957   2020-03-20  Alabama     1    106       0
# 1389  2020-03-28  Alabama     1    720       4
# 1609  2020-04-01  Alabama     1   1106      28
# 1554  2020-03-31  Alabama     1    999      13
# 1939  2020-04-07  Alabama     1   2197      64
# 1884  2020-04-06  Alabama     1   2006      53
# 1065  2020-03-22  Alabama     1    157       0
# 1829  2020-04-05  Alabama     1   1841      45
# 1119  2020-03-23  Alabama     1    196       0
# 1774  2020-04-04  Alabama     1   1633      44
# ...

# %%
df_sorted.groupby(['state']).agg('count')
# Out:
#                           date  fips  cases  deaths
# state
# Alabama                     42    42     42      42
# Alaska                      43    43     43      43
# American Samoa              15    15     15      15
# Arizona                     89    89     89      89
# Arkansas                    44    44     44      44
# California                  90    90     90      90
# Colorado                    50    50     50      50
# Connecticut                 47    47     47      47
# Delaware                    44    44     44      44
# District of Columbia        48    48     48      48
# Florida                     54    54     54      54
# Georgia                     53    53     53      53
# Guam                        40    40     40      40
# Hawaii                      49    49     49      49
# Idaho                       42    42     42      42
# Illinois                    91    91     91      91
# Indiana                     49    49     49      49
# ...
